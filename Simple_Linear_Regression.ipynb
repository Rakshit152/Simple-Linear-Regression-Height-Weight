# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("HeightWeight.csv")
df=df.drop(df.columns[0], axis=1)
df.head()
# Out:
#    Height(Inches)  Weight(Pounds)
# 0        65.78331        112.9925
# 1        71.51521        136.4873
# 2        69.39874        153.0269
# 3        68.21660        142.3354
# 4        67.78781        144.2971

# %%
plt.scatter(df['Height(Inches)'],df['Weight(Pounds)'],c='red')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Relation brtween height and weight')
# Out:
# Text(0.5, 1.0, 'Relation brtween height and weight')

# %%
df.corr()
# Out:
#                 Height(Inches)  Weight(Pounds)
# Height(Inches)        1.000000        0.502859
# Weight(Pounds)        0.502859        1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
x=df[['Height(Inches)']]
y=df['Weight(Pounds)']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train.shape
# Out:
# (18750, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[ 1.04422761],
#        [-1.26515425],
#        [-1.45158213],
#        ...,
#        [ 0.2108769 ],
#        [ 0.68769241],
#        [-0.45684105]])

# %%
x_test=scaler.transform(x_test)
x_test
# Out:
# array([[ 0.22723439],
#        [-0.05128615],
#        [-0.17655812],
#        ...,
#        [ 0.66083975],
#        [-1.80229195],
#        [-2.34404669]])

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("Slope",model.coef_)
print("Intercept",model.intercept_)
# Out:
# Slope [5.82227372]
# Intercept 127.06924639893332

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,model.predict(x_train),c='red')

# %%
model.predict(x_train)
# Out:
# array([133.1490254 , 119.70317206, 118.61773793, ..., 128.29702945,
#        131.07317986, 124.40939277])

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([128.39226723, 126.77064442, 126.04127668, ..., 130.9168363 ,
#        116.57580932, 113.42156495])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
rmse=np.sqrt(mse)
print(mse)
print(mae)
print(rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 mse=mean_squared_error(y_test,y_pred)
#       2 mae=mean_absolute_error(y_test,y_pred)
#       3 rmse=np.sqrt(mse)
#
# NameError: name 'mean_squared_error' is not defined

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.2593047494927634
